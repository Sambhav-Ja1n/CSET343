# %%
# Writing data to a file

file = open("student.txt", "w")

file.write("Name: Sambhav Jain\n")
file.write("Roll Number: E23CSEU0577\n")
file.write("Marks: 85\n")

file.close()

print("Data written successfully.")
# Out:
# Data written successfully.

# %%
# Reading data from a file

file = open("student.txt", "r")

data = file.read()

print(data)

file.close()
# Out:
# Name: Sambhav Jain
# Roll Number: E23CSEU0577
# Marks: 85

# %%
# Writing to a file

with open("student.txt", "w") as file:
    file.write("Name: Raman\n")
    file.write("Marks: 89\n")

# Reading from the file

with open("student.txt", "r") as file:
    data = file.read()

print(data)

with open("student.txt", "a") as file:
    file.write("Grade: A\n")

print("New data added.")
with open("student.txt", "r") as file:
    data = file.read()
print(data)
# Out:
# Name: Raman
# Marks: 89
#
# New data added.
# Name: Raman
# Marks: 89
# Grade: A

# %%
import pandas as pd

# Creating data
data = {
    "Name": ["Adam", "Amon", "Klien", "Leon"],
    "Age": [21, 18, 22, 19],
    "Marks": [75, 82, 98, 78]
}

# Creating DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age  Marks
# 0   Adam   21     75
# 1   Amon   18     82
# 2  Klien   22     98
# 3   Leon   19     78

# %%
print(df[["Name", "Marks"]])
# Out:
#     Name  Marks
# 0   Adam     75
# 1   Amon     82
# 2  Klien     98
# 3   Leon     78

# %%
average = df["Marks"].mean()

print("Average Marks:", average)
# Out:
# Average Marks: 83.25

# %%
print("Highest Marks:", df["Marks"].max())
# Out:
# Highest Marks: 98

# %%
df.to_csv("student.csv", index=False)

# %%
# NumPy stands for Numerical Python.
# It is mainly used for fast mathematical and numerical operations on arrays.
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
# Out:
# [10 20 30 40 50]

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print("Addition:", numbers + 5)
print("Subtraction:", numbers - 5)
print("Multiplication:", numbers * 2)
print("Division:", numbers / 2)
# Out:
# Addition: [15 25 35 45 55]
# Subtraction: [ 5 15 25 35 45]
# Multiplication: [ 20  40  60  80 100]
# Division: [ 5. 10. 15. 20. 25.]

# %%
numbers * 2
# Out:
# array([ 20,  40,  60,  80, 100])

# %%
# Matplotlib is used to create graphs and charts in Python.
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [65, 72, 78, 85, 90]

plt.plot(tests, marks)

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [65, 72, 78, 85, 90]

plt.plot(tests, marks, marker="o")

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

students = ["Adam", "Amon", "Klien", "Leon"]
marks = [75, 82, 98, 78]

plt.bar(students, marks)

plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")

plt.show()

# %%
import matplotlib.pyplot as plt

languages = ["Python", "Java", "C++", "C"]
students = [40, 30, 20, 10]

plt.pie(students, labels=languages, autopct="%1.1f%%")

plt.title("Programming Language Preference")

plt.show()

# %%
import matplotlib.pyplot as plt

study_hours = [1, 2, 3, 4, 5, 6]
marks = [45, 50, 60, 68, 78, 90]

plt.scatter(study_hours, marks)

plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Student Data:")
print(df)

# Numerical calculations on the 'Marks' column
marks = np.array(df["Marks"])

print("\nAverage Marks:", np.mean(marks))
print("Highest Marks:", np.max(marks))
print("Lowest Marks:", np.min(marks))

# Visualize the data using 'Name' and 'Marks'
plt.figure(figsize=(8,4))
plt.bar(df["Name"], df["Marks"])
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Student Data:
#     Name  Age  Marks
# 0   Adam   21     75
# 1   Amon   18     82
# 2  Klien   22     98
# 3   Leon   19     78
#
# Average Marks: 83.25
# Highest Marks: 98
# Lowest Marks: 75
