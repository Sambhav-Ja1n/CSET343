# %%
# Writing data to a file

file = open("student.txt", "w")

file.write("Name: Sambhav\n")
file.write("Roll Number: 40\n")
file.write("Marks: 85\n")

file.close()

print("Data written successfully.")
# Out:
# Data written successfully.

# %%
# Reading data from a file

file = open("student.txt", "r")

data = file.read()

print(data)

file.close()
# Out:
# Name: Sambhav
# Roll Number: 40
# Marks: 85

# %%
# Writing to a file

with open("student.txt", "w") as file:
    file.write("Name: Rahul\n")
    file.write("Marks: 85\n")

# Reading from the file

with open("student.txt", "r") as file:
    data = file.read()

print(data)

with open("student.txt", "a") as file:
    file.write("Grade: A\n")

print("New data added.")
with open("student.txt", "r") as file:
    data = file.read()
print(data)
# Out:
# Name: Rahul
# Marks: 85
#
# New data added.
# Name: Rahul
# Marks: 85
# Grade: A

# %%
# Pandas is a Python library mainly used for working with tabular data
# such as Excel sheets, CSV files, and database-like tables.
import pandas as pd

# Creating data
data = {
    "Name": ["Aman", "Riya", "Rahul", "Priya"],
    "Age": [20, 21, 19, 22],
    "Marks": [85, 92, 78, 88]
}

# Creating DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age  Marks
# 0   Aman   20     85
# 1   Riya   21     92
# 2  Rahul   19     78
# 3  Priya   22     88

# %%
print(df[["Name", "Marks"]])
# Out:
#     Name  Marks
# 0   Aman     85
# 1   Riya     92
# 2  Rahul     78
# 3  Priya     88

# %%
average = df["Marks"].mean()

print("Average Marks:", average)
# Out:
# Average Marks: 85.75

# %%
print("Highest Marks:", df["Marks"].max())
# Out:
# Highest Marks: 92

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df)
# Out:
#   student_code   full_name  age  score
# 0         S001  Aria Kline   20     88
# 1         S002  Jonas Reed   21     74
# 2         S003  Zara Nunez   19     91
# 3         S004  Malik Chen   22     67
# 4         S005   Priya Das   20     83
# 5         S006  Ethan Cruz   20     77
# 6         S007   Lina Park   21     95
# 7         S008   Omar Aziz   23     69
# 8         S009   Sophie Li   19     82
# 9         S010  Noah Grant   22     90

# %%
# NumPy stands for Numerical Python.
# It is mainly used for fast mathematical and numerical operations on arrays.
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
# Out:
# [10 20 30 40 50]

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print("Addition:", numbers + 5)
print("Subtraction:", numbers - 5)
print("Multiplication:", numbers * 2)
print("Division:", numbers / 2)
# Out:
# Addition: [15 25 35 45 55]
# Subtraction: [ 5 15 25 35 45]
# Multiplication: [ 20  40  60  80 100]
# Division: [ 5. 10. 15. 20. 25.]

# %%
numbers * 2
# Out:
# array([ 20,  40,  60,  80, 100])

# %%
# Matplotlib is used to create graphs and charts in Python.
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [65, 72, 78, 85, 90]

plt.plot(tests, marks)

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [65, 72, 78, 85, 90]

plt.plot(tests, marks, marker="o")

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

students = ["Aman", "Riya", "Rahul", "Priya"]
marks = [85, 92, 78, 88]

plt.bar(students, marks)

plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")

plt.show()

# %%
import matplotlib.pyplot as plt

languages = ["Python", "Java", "C++", "C"]
students = [40, 30, 20, 10]

plt.pie(students, labels=languages, autopct="%1.1f%%")

plt.title("Programming Language Preference")

plt.show()

# %%
import matplotlib.pyplot as plt

study_hours = [1, 2, 3, 4, 5, 6]
marks = [45, 50, 60, 68, 78, 90]

plt.scatter(study_hours, marks)

plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Read CSV file using Pandas (columns renamed to avoid 'Name'/'Marks')
df = pd.read_csv("students.csv")

# Step 2: Display DataFrame
print("Student Data:")
print(df)

# Step 3: Use NumPy for numerical calculations on the 'score' column
scores = np.array(df["score"])

print("\nAverage Score:", np.mean(scores))
print("Highest Score:", np.max(scores))
print("Lowest Score:", np.min(scores))

# Step 4: Visualize the data (use 'full_name' instead of 'Name')
plt.figure(figsize=(8,4))
plt.bar(df["full_name"], df["score"])
plt.xlabel("Participants")
plt.ylabel("Score")
plt.title("Participant Scores")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Student Data:
#   student_code   full_name  age  score
# 0         S001  Aria Kline   20     88
# 1         S002  Jonas Reed   21     74
# 2         S003  Zara Nunez   19     91
# 3         S004  Malik Chen   22     67
# 4         S005   Priya Das   20     83
# 5         S006  Ethan Cruz   20     77
# 6         S007   Lina Park   21     95
# 7         S008   Omar Aziz   23     69
# 8         S009   Sophie Li   19     82
# 9         S010  Noah Grant   22     90
#
# Average Score: 81.6
# Highest Score: 95
# Lowest Score: 67
